# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings 
warnings.filterwarnings('ignore')

# %%
fashion_mnist = keras.datasets.fashion_mnist

# %%
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
print(train_images.shape)
# Out:
# (60000, 28, 28)

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
train_images[0,24,25]
# Out:
# 58

# %%
train_labels[:19]
# Out:
# array([9, 0, 0, 3, 0, 2, 7, 2, 5, 5, 0, 9, 5, 5, 7, 9, 1, 0, 6],
#       dtype=uint8)

# %%
plt.figure()
plt.imshow(train_images[35])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
plt.figure()
plt.imshow(train_images[20000])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
model= keras.Sequential([
    keras.layers.Flatten(input_shape = (28,28)),   #Input Layer
    keras.layers.Dense(64, activation= 'relu'),   #Hidden Layer
    keras.layers.Dense(10, activation= 'softmax')  #output layer
])

# %% [markdown]
# model.compile(train_images)

# %%
model.compile(optimizer='adam', loss= 'sparse_categorical_crossentropy', metrics= ['accuracy'] )

# %%
model.fit(train_images, train_labels, epochs = 10) #We pass the data, labels and epochs and watch the magic!
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.7738 - loss: 0.6680
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8589 - loss: 0.3983
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8738 - loss: 0.3558
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8814 - loss: 0.3249
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8880 - loss: 0.3077
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8876 - loss: 0.3020
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8929 - loss: 0.2939
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.8993 - loss: 0.2728
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9058 - loss: 0.2569
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9039 - loss: 0.2596

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels,batch_size= 8,return_dict= True,verbose= 2)
print(test_acc)
# Out:
# 1250/1250 - 3s - 3ms/step - accuracy: 0.8832 - loss: 0.3352
# loss

# %%
prediction = model.predict(test_images)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
np.argmax(prediction[10])
# Out:
# 4

# %%
test_labels[10]
# Out:
# 4
